# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df_2022 = pd.read_excel('data/Nedel_ipc.xlsx', sheet_name='2022', skiprows=3)
df_2022.dropna(axis=0, inplace=True)

df_2023 = pd.read_excel('data/Nedel_ipc.xlsx', sheet_name='2023', skiprows=3)
df_2023.dropna(axis=0, inplace=True)

df_2024 = pd.read_excel('data/Nedel_ipc.xlsx', sheet_name='2024', skiprows=3)
df_2024.dropna(axis=0, inplace=True)

df_2025 = pd.read_excel('data/Nedel_ipc.xlsx', sheet_name='2025', skiprows=3)
df_2025.dropna(axis=0, inplace=True)

df_2022.shape, df_2023.shape, df_2024.shape, df_2025.shape
# Out:
# ((108, 52), (110, 52), (109, 52), (110, 41))

# %%
def extract_dt(str_date, year):
    months = {
        '**': '01', 'января**': '01',
        'января': '01', 'февраля': '02', 'марта': '03',
        'апреля': '04', 'мая': '05', 'июня': '06',
        'июля': '07', 'августа': '08', 'сентября': '09',
        'октября': '10', 'ноября': '11', 'декабря': '12'
    }
    data = str_date.split()
    d = ''.join(filter(str.isdigit, data))
    m = months[data[-1]]
    return pd.to_datetime(year+'-'+m+'-'+d)

# %%
df_2022.columns = ['Наименование'] + [extract_dt(data, '2022') for data in df_2022.columns[1:]]
df_2022.set_index('Наименование', inplace=True)
df_2023.columns = ['Наименование'] + [extract_dt(data, '2023') for data in df_2023.columns[1:]]
df_2023.set_index('Наименование', inplace=True)
df_2024.columns = ['Наименование'] + [extract_dt(data, '2024') for data in df_2024.columns[1:]]
df_2024.set_index('Наименование', inplace=True)
df_2025.columns = ['Наименование'] + [extract_dt(data, '2025') for data in df_2025.columns[1:]]
df_2025.set_index('Наименование', inplace=True)

# %%
df_2022.loc['Поездка на отдых в Турцию, поездка'] = df_2022.loc['Поездка на отдых в Турцию, поездка']\
                                                               .map({'…': '0'})\
                                                               .fillna(df_2022.loc['Поездка на отдых в Турцию, поездка'])

# %%
df_2022 = df_2022.apply(pd.to_numeric, errors='coerce')

# %%
fig, ax = plt.subplots(1, figsize=(21, 5))
ax.plot(df_2022.sum(axis=0), marker='o')
ax.plot(df_2023.sum(axis=0), marker='o')
ax.plot(df_2024.sum(axis=0), marker='o')
ax.plot(df_2025.sum(axis=0), marker='o')
ax.set_title('All Prices are Summarized')
# Out:
# Text(0.5, 1.0, 'All Prices are Summarized')

# %% [markdown]
# # 1. Введение в анализ и прогнозирование временных рядов

# %% [markdown]
# ## § 1.1. Типы экономических прогнозов

# %% [markdown]
# Прогнозы:
# - *поисковые*. Что вероятнее всего ожидать в будущем?
# - *нормативные*. Каким образом нужно изменить условия, чтобы достичь заданного состояния прогнозируемого объекта?
#
# &nbsp;
#
# По времени:
# - *оперативные*. До 1 месяца
# - *краткосрочные*. 1-12 месяцев
# - *среднесрочные*. от 1 года, но не больше 5 лет
# - *долгосрочные*. Более 5 лет
#
# &nbsp;
#
# Временные ряды:
#  - *моментные*. В качестве показателя времени указываются отдельные моменты времени (даты)
#  - *интервальные*. В качестве показателя времени указываются сутки, месяцы, кварталы, полугодия и тд
#
# &nbsp;
#
# Уровни временного ряда (отдельные наблюдения):
# - *абсолютные*
# - *относительные*
# - *средние*
#
# &nbsp;
#
# Интервальные ряды с абсолютными величинами можно суммировать (св-во аддитивности).\
# В моментном ряде имеет смысл  расчет разностей уровней, харак-щих изменения показателя за некоторый отрезок времени.
#
# &nbsp;
#
# "*Смыкание рядов динамики*" - приведение уровней динамики к сопоставиму виду.

# %% [markdown]
# ## § 1.2. Основные аналитические характеристики динамики и их использование при прогнозировании

# %% [markdown]
# Основные аналитические показатели:
# <table>
#     <thead>
#         <tr>
#             <th></th>
#             <th>Абсолютные приросты</th>
#             <th>Темпы роста</th>
#             <th>Темпы прироста</th>
#         </tr>
#     </thead>
#     <tr>
#         <th>Цепной</th>
#         <td>
#             $$
#             \normalsize\Delta y_t = y_t - y_{t-1}
#             $$
#         </td>
#         <td>
#             $$
#             \normalsize T_t = \frac{y_t}{y_{t-1}}100\%
#             $$
#         </td>
#         <td>
#             $$
#             \normalsize K_t = T_t - 100\%
#             $$
#         </td>
#     </tr>
#     <tr>
#         <th>Базисный</th>
#         <td>
#             $$
#             \normalsize\Delta y_t^b = y_t - y_b
#             $$
#         </td>
#         <td>
#             $$
#             \normalsize T_t^b = \frac{y_t}{y_b}100\%
#             $$
#         </td>
#         <td>
#             $$
#             \normalsize K_t^b = T_t^b - 100\%
#             $$
#         </td>
#     </tr>
#     <tr>
#         <th>Средний</th>
#         <td>
#             $$
#             \normalsize \overline{\Delta y} = \frac{y_n - y_1}{n - 1}
#             $$
#         </td>
#         <td>
#             $$
#             \normalsize \overline{T} = \sqrt[n-1]\frac{y_n}{y_1}100\%
#             $$
#         </td>
#         <td>
#             $$
#             \normalsize \overline{K} = \overline{K} - 100\%
#             $$
#         </td>
#     </tr>
# </table>
#
# $\normalsize y_t$ - текущий уровень временного ряда
#
# $\normalsize y_b$ - уровень временного ряда принятый за базу сравнения
#
# $\normalsize n$ - длина временного ряда

# %% [markdown]
# Описание динамики ряда с помощью среднего абсолютного прироста соответствует  его представлению в виде прямой, проведенной через две крайние точки. В этом случае, чтобы получить прогноз на L шагов вперед:
# $$
# \normalsize \hat{y}_{n+L} = y_n + L\overline{\Delta y}
# $$
#
# $\normalsize y_n$ - значение в последней n-й точке ряда
#
# $\normalsize\hat{y}_{n+L}$ -прогнозная оценка значения (n + L)-го уровня
#
# $\normalsize \overline{\Delta y}$ - значение среднего абсолютного прироста
#
# Очевидно, что такой подход к  получению прогнозного значения корректен, если хар-р развития близок к **линейному**

# %%
df = pd.DataFrame(
    index=pd.date_range(start='2020', end='2025', freq='Y'),
    columns=['volume'],
    data=np.array([26., 28.5, 32.4, 35.3, 37.7])
)
df
# Out:
#             volume
# 2020-12-31    26.0
# 2021-12-31    28.5
# 2022-12-31    32.4
# 2023-12-31    35.3
# 2024-12-31    37.7

# %%
df['Period-to-period absolute change'] = df['volume'].diff() # цепной абсолютный прирост
df
# Out:
#             volume  Period-to-period absolute change
# 2020-12-31    26.0                               NaN
# 2021-12-31    28.5                               2.5
# 2022-12-31    32.4                               3.9
# 2023-12-31    35.3                               2.9
# 2024-12-31    37.7                               2.4

# %%
# средний абсолютный прирост
mean_abs_change = np.round((df['volume'].iloc[-1]-df['volume'].iloc[0])/(df.shape[0]-1), 1)
mean_abs_change
# Out:
# 2.9

# %%
# прогноз
forecast = df['volume'].iloc[-1] + mean_abs_change
forecast
# Out:
# 40.6

# %%
fig, ax = plt.subplots(1, figsize=(21, 5))

ax.plot(df['volume'].index, df['volume'].to_list(), marker='o', label='Production Volume')
ax.plot(pd.date_range(start='2024', end='2026', freq='Y'),
        [df['volume'].iloc[-1], forecast], marker='o', label='Forecast')
ax.set_xticks(pd.date_range(start='2020', end='2026', freq='Y'))
ax.legend()

# %%
beef = df_2022.loc['Говядина (кроме бескостного мяса), кг']

mean_abs_change = np.round((beef.iloc[-2]-beef.iloc[0])/(len(beef)-1), 3)
forecast = np.round((beef.iloc[-2] + mean_abs_change), 3)

# %%
beef[-2:].index
# Out:
# DatetimeIndex(['2022-12-19', '2022-12-26'], dtype='datetime64[ns]', freq=None)

# %%
fig, ax = plt.subplots(1, figsize=(21, 5))

ax.plot(beef, marker='o', label='Beef real price')
ax.plot(beef[-2:].index, [beef[-2], forecast], marker='o', label='Beef forecast price')
ax.legend()

# %% [markdown]
# *Темп роста* хар-ет отношение двух сравниваемых уровней ряда, как правило, выраженное в процентах.
#
# &nbsp;
#
# Цепной темп роста:
#
# $$
# \normalsize T_t = \frac{y_t}{y_{t-1}}100\%
# $$
#
# Базисный темп роста:
#
# $$
# \normalsize T_t = \frac{y_t}{y_b}100\%
# $$

# %%
beef_df = pd.DataFrame(beef)
beef_df.columns = ['price']
beef_df.head()
# Out:
#              price
# 2022-01-10  100.58
# 2022-01-14  100.25
# 2022-01-21  100.25
# 2022-01-28  100.33
# 2022-02-04  100.58

# %%
data = (beef_df['price'] / beef_df['price'].shift(-1))*100

fig, ax = plt.subplots(1, figsize=(21, 5))
ax.bar(data.index, data)
ax.plot(data, marker='o')
ax.set_yscale('log')
